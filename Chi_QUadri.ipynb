# %%
#Facciamo un plot per l'andamento dei chi2 ridotti per i diversi modelli di fitting a 25 e 175 GeV

chi2_ndof_25=[64.5, 48.97, 54.18, 16.7]
chi2_ndof_175=[56.90, 10.88, 30.35, 2.5]
modelli=["Gaussiana","CrystalBall","Voigt","Voigt+Gaussiana"]
