# %%
import json

with open("fit_values.json", "r") as f:
    values = json.load(f)


with open("fit_errors.json", "r") as f:
    errors = json.load(f)

#Siamo riusciti a passare i dati dei fit al file json, ora possiamo usarli per fare i grafici.

#Interpoliamo le norme

masse=[25, 50, 75, 100, 125, 150, 175, 200]
fit_MH_values=values
fit_MH_errors=errors

print(fit_MH_values)
print(fit_MH_errors)
# Out:
# {'MH25': {'norm': 0.9508152528989859, 'mu': 25.54969272049765, 'sigma': 2.844057736211518, 'gamma': 0.284418290713378}, 'MH50': {'norm': 0.9585368733248889, 'mu': 50.52188657149526, 'sigma': 3.596765389507484, 'gamma': 2.1252404981561903}, 'MH75': {'norm': 0.9943706369723083, 'mu': 76.34689685285313, 'sigma': 5.419200810046673, 'gamma': 3.3275478555406237}, 'MH100': {'norm': 1.0310280978554043, 'mu': 101.97504515998283, 'sigma': 6.983487116685243, 'gamma': 3.65821952968712}, 'MH200': {'norm': 0.9800552122194244, 'mu': 200.93117749041895, 'sigma': 14.060459250151368, 'gamma': 2.3731151528940337}, 'MH125': {'norm': 1.0543358878617586, 'mu': 126.61423390900535, 'sigma': 8.409705373923497, 'gamma': 4.829092739712042}, 'MH150': {'norm': 0.928659701594041, 'mu': 149.99999995412458, 'sigma': 9.576459500312987, 'gamma': 7.6099142557647825}, 'MH175': {'norm': 1.0573040274165961, 'mu': 177.30337336825957, 'sigma': 11.61699522957357, 'gamma': 5.734426541113037}}
# {'MH25_errors': {'norm': 0.004119833545233603, 'mu': 0.017533304649871795, 'sigma': 0.0228152570266984, 'gamma': 0.010743581189916168}, 'MH50_errors': {'norm': 0.004173521723385876, 'mu': 0.02670182000668575, 'sigma': 0.04738789120821307, 'gamma': 0.03202545795397205}, 'MH75_errors': {'norm': 0.004249180111868342, 'mu': 0.03901192633889394, 'sigma': 0.06753208733332938, 'gamma': 0.049899148768983714}, 'MH100_errors': {'norm': 0.004740518478347108, 'mu': 0.0494723201270304, 'sigma': 0.09298790163829196, 'gamma': 0.07616263031011927}, 'MH200_errors': {'norm': 0.0059496891702595055, 'mu': 0.10536236689462442, 'sigma': 0.19789115032979243, 'gamma': 0.21364182420778066}, 'MH125_errors': {'norm': 0.005081234514561848, 'mu': 0.06222859749561849, 'sigma': 0.12905919355924222, 'gamma': 0.11368323021141169}, 'MH150_errors': {'norm': 0.004223321355313767, 'mu': 0.0021636882576245853, 'sigma': 0.15590641831268925, 'gamma': 0.11776514178475628}, 'MH175_errors': {'norm': 0.0061319114036518085, 'mu': 0.09177286773847015, 'sigma': 0.21795430750681533, 'gamma': 0.22031218002213482}}

# %%
# Estraggo tutti i 'norm' iterando sui valori del dizionario principale
norms = [fit["norm"] for fit in fit_MH_values.values()]
norms_errors = [fit["norm"] for fit in fit_MH_errors.values()]

print(norms)
print(norms_errors)
# Out:
# [0.9508152528989859, 0.9585368733248889, 0.9943706369723083, 1.0310280978554043, 0.9800552122194244, 1.0543358878617586, 0.928659701594041, 1.0573040274165961]
# [0.004119833545233603, 0.004173521723385876, 0.004249180111868342, 0.004740518478347108, 0.0059496891702595055, 0.005081234514561848, 0.004223321355313767, 0.0061319114036518085]

# %%
#Facciamo la prima interpolazione, dopo vedremo come aggiungere gli erri 

from matplotlib import pyplot as plt

fig=plt.figure()
plt.plot(masse, norms, marker='o')
plt.xlabel("Massa")
plt.errorbar(masse, norms, yerr=norms_errors, fmt='o', capsize=5)
plt.ylabel("Norma")
plt.title("Interpolazione delle norme in funzione della massa")
plt.grid()
plt.show()

# %%
mu=[fit["mu"] for fit in fit_MH_values.values()]
mu_errors=[fit["mu"] for fit in fit_MH_errors.values()]

print(mu)
print(mu_errors)

fig=plt.figure()
plt.plot(masse, mu, marker='o')
plt.xlabel("Massa")
plt.errorbar(masse, mu, yerr=mu_errors, fmt='o', capsize=5)
plt.ylabel("Mu")
plt.title("Interpolazione di mu in funzione della massa")
plt.grid()
plt.show()
# Out:
# [25.54969272049765, 50.52188657149526, 76.34689685285313, 101.97504515998283, 200.93117749041895, 126.61423390900535, 149.99999995412458, 177.30337336825957]
# [0.017533304649871795, 0.02670182000668575, 0.03901192633889394, 0.0494723201270304, 0.10536236689462442, 0.06222859749561849, 0.0021636882576245853, 0.09177286773847015]

# %%
#Ora le sigma

sigma=[fit["sigma"] for fit in fit_MH_values.values()]
sigma_errors=[fit["sigma"] for fit in fit_MH_errors.values()]   

print(sigma)
print(sigma_errors)

fig=plt.figure()
plt.plot(masse, sigma, marker='o')
plt.xlabel("Massa")
plt.errorbar(masse, sigma, yerr=sigma_errors, fmt='o', capsize=5)
plt.ylabel("Sigma")
plt.title("Interpolazione di sigma in funzione della massa")
plt.grid()
plt.show()
# Out:
# [2.844057736211518, 3.596765389507484, 5.419200810046673, 6.983487116685243, 14.060459250151368, 8.409705373923497, 9.576459500312987, 11.61699522957357]
# [0.0228152570266984, 0.04738789120821307, 0.06753208733332938, 0.09298790163829196, 0.19789115032979243, 0.12905919355924222, 0.15590641831268925, 0.21795430750681533]

# %%
#Ora per le gamma

gamma=[fit["gamma"] for fit in fit_MH_values.values()]
gamma_errors=[fit["gamma"] for fit in fit_MH_errors.values()]       

print(gamma)
print(gamma_errors)

fig=plt.figure()
plt.plot(masse, gamma, marker='o')
plt.xlabel("Massa (GeV)")
plt.errorbar(masse, gamma, yerr=gamma_errors, fmt='o', capsize=5)
plt.ylabel("Gamma")
plt.title("Interpolazione di gamma in funzione della massa")
plt.grid()
plt.show()
# Out:
# [0.284418290713378, 2.1252404981561903, 3.3275478555406237, 3.65821952968712, 2.3731151528940337, 4.829092739712042, 7.6099142557647825, 5.734426541113037]
# [0.010743581189916168, 0.03202545795397205, 0.049899148768983714, 0.07616263031011927, 0.21364182420778066, 0.11368323021141169, 0.11776514178475628, 0.22031218002213482]
