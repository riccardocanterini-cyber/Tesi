# %%
import json
import numpy as np
with open("fit_results.json", "r") as f:
    results = json.load(f)

fit_MH_25 = results["MH25"]
fit_MH_50 = results["MH50"]
fit_MH_75 = results["MH75"]
print(fit_MH_25)
print(fit_MH_50)
print(fit_MH_75)


#Siamo riusciti a passare i dati dei fit al file json, ora possiamo usarli per fare i grafici.

#Interpoliamo le norme

masse=[25, 50, 75]
fit_MH_values=results 

print(fit_MH_values)
# Out:
# {'norm': 0.9508152528989859, 'mu': 25.54969272049765, 'sigma': 2.844057736211518, 'gamma': 0.284418290713378}
# {'norm': 0.9585368733248889, 'mu': 50.52188657149526, 'sigma': 3.596765389507484, 'gamma': 2.1252404981561903}
# {'norm': 0.9943706369723083, 'mu': 76.34689685285313, 'sigma': 5.419200810046673, 'gamma': 3.3275478555406237}
# {'MH25': {'norm': 0.9508152528989859, 'mu': 25.54969272049765, 'sigma': 2.844057736211518, 'gamma': 0.284418290713378}, 'MH50': {'norm': 0.9585368733248889, 'mu': 50.52188657149526, 'sigma': 3.596765389507484, 'gamma': 2.1252404981561903}, 'MH75': {'norm': 0.9943706369723083, 'mu': 76.34689685285313, 'sigma': 5.419200810046673, 'gamma': 3.3275478555406237}}

# %%
# Estraggo tutti i 'norm' iterando sui valori del dizionario principale
lista_tutti_norm = [sotto_dizionario["norm"] for sotto_dizionario in fit_MH_values.values()]

print(lista_tutti_norm)
# Output: [0.9508152528989859, 0.9585368733248889, 0.9943706369723083]
# Out:
# [0.9508152528989859, 0.9585368733248889, 0.9943706369723083]
