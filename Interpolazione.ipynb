# %%
import json

with open("fit_values.json", "r") as f:
    values = json.load(f)


with open("fit_errors.json", "r") as f:
    errors = json.load(f)

#Siamo riusciti a passare i dati dei fit al file json, ora possiamo usarli per fare i grafici.

#Interpoliamo le norme

masse=[25, 50, 75, 100, 125, 150, 175, 200, 250, 350, 450, 500]
fit_MH_values=values
fit_MH_errors=errors

print(fit_MH_values)
print(fit_MH_errors)
# Out:
# {'MH25': {'norm': 0.9508152528989859, 'mu': 25.54969272049765, 'sigma': 2.844057736211518, 'gamma': 0.284418290713378}, 'MH50': {'norm': 0.9585368733248889, 'mu': 50.52188657149526, 'sigma': 3.596765389507484, 'gamma': 2.1252404981561903}, 'MH75': {'norm': 0.9943706369723083, 'mu': 76.34689685285313, 'sigma': 5.419200810046673, 'gamma': 3.3275478555406237}, 'MH100': {'norm': 1.0, 'mu': 100.0, 'sigma': 5.0, 'gamma': 1.0}, 'MH200': {'norm': 0.7796882337578827, 'mu': 200.2780170632862, 'sigma': 10.925645883569494, 'gamma': 7.5492906204296535}, 'MH125': {'norm': 0.9763952561798271, 'mu': 126.43979869720671, 'sigma': 7.489047008089692, 'gamma': 6.297770299659986}, 'MH150': {'norm': 0.928659701594041, 'mu': 149.99999995412458, 'sigma': 9.576459500312987, 'gamma': 7.6099142557647825}, 'MH175': {'norm': 0.8405110644568667, 'mu': 176.56930756468523, 'sigma': 13.21637710876557, 'gamma': 5.1968959268036405}}
# {'MH25_errors': {'norm': 0.004119833545233603, 'mu': 0.017533304649871795, 'sigma': 0.0228152570266984, 'gamma': 0.010743581189916168}, 'MH50_errors': {'norm': 0.004173521723385876, 'mu': 0.02670182000668575, 'sigma': 0.04738789120821307, 'gamma': 0.03202545795397205}, 'MH75_errors': {'norm': 0.004249180111868342, 'mu': 0.03901192633889394, 'sigma': 0.06753208733332938, 'gamma': 0.049899148768983714}, 'MH100_errors': {'norm': nan, 'mu': nan, 'sigma': nan, 'gamma': nan}, 'MH200_errors': {'norm': 0.004027377703588132, 'mu': 0.11034690228341049, 'sigma': 0.18635594911053044, 'gamma': 0.1725504251603498}, 'MH125_errors': {'norm': 0.004265438328435803, 'mu': 0.06293470329590178, 'sigma': 0.11961028735184431, 'gamma': 0.08888215163851987}, 'MH150_errors': {'norm': 0.004223321355313767, 'mu': 0.0021636882576245853, 'sigma': 0.15590641831268925, 'gamma': 0.11776514178475628}, 'MH175_errors': {'norm': 0.0040186081012544995, 'mu': 0.09511359600907099, 'sigma': 0.14751181107310707, 'gamma': 0.11721249852725046}}

# %%
# Estraggo tutti i 'norm' iterando sui valori del dizionario principale
norms = [fit["norm"] for fit in fit_MH_values.values()]
norms_errors = [fit["norm"] for fit in fit_MH_errors.values()]

print(norms)
print(norms_errors)
# Out:
# [0.9508152528989859, 0.9585368733248889, 0.9943706369723083, 1.0, 0.7796882337578827, 0.9763952561798271, 0.928659701594041, 0.8405110644568667]
# [0.004119833545233603, 0.004173521723385876, 0.004249180111868342, nan, 0.004027377703588132, 0.004265438328435803, 0.004223321355313767, 0.0040186081012544995]

# %%
#Facciamo la prima interpolazione, dopo vedremo come aggiungere gli erri 

from matplotlib import pyplot as plt

fig=plt.figure()
plt.plot(masse, norms, marker='o')
plt.xlabel("Massa")
plt.errorbar(masse, norms, yerr=norms_errors, fmt='o', capsize=5)
plt.ylabel("Norma")
plt.title("Interpolazione delle norme in funzione della massa")
plt.grid()
plt.show()

# %%
mu=[fit["mu"] for fit in fit_MH_values.values()]
mu_errors=[fit["mu"] for fit in fit_MH_errors.values()]

print(mu)
print(mu_errors)

fig=plt.figure()
plt.plot(masse, mu, marker='o')
plt.xlabel("Massa")
plt.errorbar(masse, mu, yerr=mu_errors, fmt='o', capsize=5)
plt.ylabel("Mu")
plt.title("Interpolazione di mu in funzione della massa")
plt.grid()
plt.show()
# Out:
# [25.54969272049765, 50.52188657149526, 76.34689685285313, 100.0, 200.2780170632862, 126.43979869720671, 149.99999995412458, 176.56930756468523]
# [0.017533304649871795, 0.02670182000668575, 0.03901192633889394, nan, 0.11034690228341049, 0.06293470329590178, 0.0021636882576245853, 0.09511359600907099]

# %%
#Ora le sigma

sigma=[fit["sigma"] for fit in fit_MH_values.values()]
sigma_errors=[fit["sigma"] for fit in fit_MH_errors.values()]   

print(sigma)
print(sigma_errors)

fig=plt.figure()
plt.plot(masse, sigma, marker='o')
plt.xlabel("Massa")
plt.errorbar(masse, sigma, yerr=sigma_errors, fmt='o', capsize=5)
plt.ylabel("Sigma")
plt.title("Interpolazione di sigma in funzione della massa")
plt.grid()
plt.show()
# Out:
# [2.844057736211518, 3.596765389507484, 5.419200810046673, 5.0, 10.925645883569494, 7.489047008089692, 9.576459500312987, 13.21637710876557]
# [0.0228152570266984, 0.04738789120821307, 0.06753208733332938, nan, 0.18635594911053044, 0.11961028735184431, 0.15590641831268925, 0.14751181107310707]

# %%
#Ora per le gamma

gamma=[fit["gamma"] for fit in fit_MH_values.values()]
gamma_errors=[fit["gamma"] for fit in fit_MH_errors.values()]       

print(gamma)
print(gamma_errors)

fig=plt.figure()
plt.plot(masse, gamma, marker='o')
plt.xlabel("Massa (GeV)")
plt.errorbar(masse, gamma, yerr=gamma_errors, fmt='o', capsize=5)
plt.ylabel("Gamma")
plt.title("Interpolazione di gamma in funzione della massa")
plt.grid()
plt.show()
# Out:
# [0.284418290713378, 2.1252404981561903, 3.3275478555406237, 1.0, 7.5492906204296535, 6.297770299659986, 7.6099142557647825, 5.1968959268036405]
# [0.010743581189916168, 0.03202545795397205, 0.049899148768983714, nan, 0.1725504251603498, 0.08888215163851987, 0.11776514178475628, 0.11721249852725046]
